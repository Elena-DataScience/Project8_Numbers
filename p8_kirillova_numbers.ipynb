# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Загрузка-библиотек" data-toc-modified-id="Загрузка-библиотек-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка библиотек</a></span></li><li><span><a href="#Загрузка-датасетов-и-вывод-информации-о-них" data-toc-modified-id="Загрузка-датасетов-и-вывод-информации-о-них-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Загрузка датасетов и вывод информации о них</a></span></li><li><span><a href="#Проверка-на-дубликаты" data-toc-modified-id="Проверка-на-дубликаты-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Проверка на дубликаты</a></span><ul class="toc-item"><li><span><a href="#Датасет-тестовой-выборки" data-toc-modified-id="Датасет-тестовой-выборки-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Датасет тестовой выборки</a></span></li><li><span><a href="#Датасет-обучающей-выборки" data-toc-modified-id="Датасет-обучающей-выборки-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Датасет обучающей выборки</a></span></li><li><span><a href="#Датасет-исходных-данных" data-toc-modified-id="Датасет-исходных-данных-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Датасет исходных данных</a></span></li></ul></li><li><span><a href="#Проверка-числовых-значений-в-датасетах" data-toc-modified-id="Проверка-числовых-значений-в-датасетах-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Проверка числовых значений в датасетах</a></span><ul class="toc-item"><li><span><a href="#Датасет-тестовой-выборки" data-toc-modified-id="Датасет-тестовой-выборки-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Датасет тестовой выборки</a></span></li><li><span><a href="#Датасет-обучающей-выборки" data-toc-modified-id="Датасет-обучающей-выборки-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Датасет обучающей выборки</a></span></li><li><span><a href="#Датасет-исходных-данных" data-toc-modified-id="Датасет-исходных-данных-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>Датасет исходных данных</a></span></li></ul></li><li><span><a href="#Функция-анализа-пропусков" data-toc-modified-id="Функция-анализа-пропусков-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Функция анализа пропусков</a></span></li><li><span><a href="#Вычисление-MAE-на-обучающей-выборке" data-toc-modified-id="Вычисление-MAE-на-обучающей-выборке-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Вычисление MAE на обучающей выборке</a></span></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li><li><span><a href="#Определение-столбцов-для-модели-и-их-обраотка" data-toc-modified-id="Определение-столбцов-для-модели-и-их-обраотка-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Определение столбцов для модели и их обраотка</a></span></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-1.10"><span class="toc-item-num">1.10&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li><li><span><a href="#Гистограммы-обогащения-концентрата" data-toc-modified-id="Гистограммы-обогащения-концентрата-1.11"><span class="toc-item-num">1.11&nbsp;&nbsp;</span>Гистограммы обогащения концентрата</a></span></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-1.12"><span class="toc-item-num">1.12&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Анализ-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки" data-toc-modified-id="Анализ-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Анализ концентрации металлов (Au, Ag, Pb) на различных этапах очистки</a></span></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li><li><span><a href="#Гистограммы-перед-флотацией-и-первичной-очисткой" data-toc-modified-id="Гистограммы-перед-флотацией-и-первичной-очисткой-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Гистограммы перед флотацией и первичной очисткой</a></span></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li><li><span><a href="#Суммарная-концентрация-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах" data-toc-modified-id="Суммарная-концентрация-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Суммарная концентрация всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах</a></span></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li><li><span><a href="#-Комментарий-ревьюера-v2" data-toc-modified-id="-Комментарий-ревьюера-v2-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span> Комментарий ревьюера v2</a></span></li><li><span><a href="#-Комментарий-ревьюера-v3" data-toc-modified-id="-Комментарий-ревьюера-v3-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span> Комментарий ревьюера v3</a></span></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Функция-для-вычисления-sMAPE" data-toc-modified-id="Функция-для-вычисления-sMAPE-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Функция для вычисления sMAPE</a></span></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li><li><span><a href="#Обучение-моделей-и-оценка-их-качества" data-toc-modified-id="Обучение-моделей-и-оценка-их-качества-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Обучение моделей и оценка их качества</a></span></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li><li><span><a href="#-Комментарий-ревьюера-v2" data-toc-modified-id="-Комментарий-ревьюера-v2-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span> Комментарий ревьюера v2</a></span></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li><li><span><a href="#Лучший-результат-тренировочной-выборки" data-toc-modified-id="Лучший-результат-тренировочной-выборки-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Лучший результат тренировочной выборки</a></span></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li><li><span><a href="#-Комментарий-ревьюера-v2" data-toc-modified-id="-Комментарий-ревьюера-v2-3.11"><span class="toc-item-num">3.11&nbsp;&nbsp;</span> Комментарий ревьюера v2</a></span></li><li><span><a href="#Ошибка-тестовой-выборки" data-toc-modified-id="Ошибка-тестовой-выборки-3.12"><span class="toc-item-num">3.12&nbsp;&nbsp;</span>Ошибка тестовой выборки</a></span></li><li><span><a href="#Анализ-константной-модели" data-toc-modified-id="Анализ-константной-модели-3.13"><span class="toc-item-num">3.13&nbsp;&nbsp;</span>Анализ константной модели</a></span></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-3.14"><span class="toc-item-num">3.14&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-3.15"><span class="toc-item-num">3.15&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.
#
#         Технологический процесс:
#
# - Rougher feed — исходное сырье
# - Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
# - Xanthate — ксантогенат (промотер, или активатор флотации);
# - Sulphate — сульфат (на данном производстве сульфид натрия);
# - Depressant — депрессант (силикат натрия).
# - Rougher process (англ. «грубый процесс») — флотация
# - Rougher tails — отвальные хвосты
# - Float banks — флотационная установка
# - Cleaner process — очистка
# - Rougher Au — черновой концентрат золота
# - Final Au — финальный концентрат золота
#
#         Параметры этапов:
#
# - air amount — объём воздуха
# - fluid levels — уровень жидкости
# - feed size — размер гранул сырья
# - feed rate — скорость подачи

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ###  Загрузка библиотек

# %%
# Загружаем библиотеки
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.metrics import make_scorer
from sklearn.pipeline import  make_pipeline
from sklearn.impute import KNNImputer
from sklearn.dummy import DummyRegressor
from sklearn.model_selection import RandomizedSearchCV
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Загрузка датасетов и вывод информации о них

# %%
# Подгрузим данные и посмотрим по ним информацию
df_train = pd.read_csv('/datasets/gold_recovery_train_new.csv')
df_test = pd.read_csv('/datasets/gold_recovery_test_new.csv')
df_full = pd.read_csv('/datasets/gold_recovery_full_new.csv')

# %%
#Отобразим первые 5 строк каждого датасета
#print('Обучающая выборка:', df_train.head(5))
#print('Тестовая выборка:', df_test.head(5))
#print('Исходные данные:', df_full.head(5))

# %%
#Просмотрим общую информации о каждом датасете
print('Общая информация об обучающей выборке:\n')
df_train.info()
# Out:
# Общая информация об обучающей выборке:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14149 non-null  object
#  1   final.output.concentrate_ag                         14148 non-null  float64
#  2   final.output.concentrate_pb                         14148 non-null  float64
#  3   final.output.concentrate_sol                        13938 non-null  float64
#  4   final.output.concentrate_au                         14149 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_ag                                14149 non-null  float64
#  7   final.output.tail_pb                                14049 non-null  float64
# ...

# %%
print('\nОбщая информация о тестовой выборке:\n')
df_test.info()
# Out:
# Общая информация о тестовой выборке:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        5290 non-null   object
#  1   primary_cleaner.input.sulfate               5286 non-null   float64
#  2   primary_cleaner.input.depressant            5285 non-null   float64
#  3   primary_cleaner.input.feed_size             5290 non-null   float64
#  4   primary_cleaner.input.xanthate              5286 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
# ...

# %%
print('\nОбщая информация об исходных данных\n')
df_full.info()
# Out:
# Общая информация об исходных данных
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   final.output.concentrate_ag                         19438 non-null  float64
#  2   final.output.concentrate_pb                         19438 non-null  float64
#  3   final.output.concentrate_sol                        19228 non-null  float64
#  4   final.output.concentrate_au                         19439 non-null  float64
#  5   final.output.recovery                               19439 non-null  float64
#  6   final.output.tail_ag                                19438 non-null  float64
#  7   final.output.tail_pb                                19338 non-null  float64
# ...

# %% [markdown]
# ### Проверка на дубликаты

# %% [markdown]
# #### Датасет тестовой выборки

# %%
df_test.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Датасет обучающей выборки

# %%
df_train.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Датасет исходных данных

# %%
df_full.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Проверка числовых значений в датасетах

# %% [markdown]
# #### Датасет тестовой выборки

# %%
df_test.describe()
# Out:
#        primary_cleaner.input.sulfate  primary_cleaner.input.depressant  \
# count                    5286.000000                       5285.000000
# mean                      174.839652                          8.683596
# std                        43.027080                          3.072050
# min                         2.566156                          0.003839
# 25%                       147.121401                          6.489555
# 50%                       177.828489                          8.052207
# 75%                       208.125438                         10.027764
# max                       265.983123                         40.000000
#
#        primary_cleaner.input.feed_size  primary_cleaner.input.xanthate  \
# count                      5290.000000                     5286.000000
# mean                          7.266339                        1.383803
# std                           0.610219                        0.643474
# ...

# %% [markdown]
# #### Датасет обучающей выборки

# %%
df_train.describe()
# Out:
#        final.output.concentrate_ag  final.output.concentrate_pb  \
# count                 14148.000000                 14148.000000
# mean                      5.142034                    10.132960
# std                       1.369586                     1.654930
# min                       0.000000                     0.000000
# 25%                       4.211620                     9.297355
# 50%                       4.994652                    10.297144
# 75%                       5.859540                    11.170603
# max                      16.001945                    17.031899
#
#        final.output.concentrate_sol  final.output.concentrate_au  \
# count                  13938.000000                 14149.000000
# mean                       9.202849                    44.003792
# std                        2.790516                     4.905261
# min                        0.000000                     0.000000
# ...

# %% [markdown]
# #### Датасет исходных данных

# %%
df_full.describe()
# Out:
#        final.output.concentrate_ag  final.output.concentrate_pb  \
# count                 19438.000000                 19438.000000
# mean                      5.168470                     9.978895
# std                       1.372348                     1.669240
# min                       0.000000                     0.000000
# 25%                       4.251240                     9.137262
# 50%                       5.066094                    10.102433
# 75%                       5.895527                    11.035769
# max                      16.001945                    17.031899
#
#        final.output.concentrate_sol  final.output.concentrate_au  \
# count                  19228.000000                 19439.000000
# mean                       9.501224                    44.076513
# std                        2.787537                     5.129784
# min                        0.000000                     0.000000
# ...

# %% [markdown]
# Из-за большого количества данных сложно анализировать какое количество пропусков присутсвует во фреймах, так что напишем для этого функцию

# %% [markdown]
# ### Функция анализа пропусков

# %%
def show_isna(df):
    for column in df.columns:
        print('Количество пропусков в каждом столбце:')    
        print(df.isna().mean())

# %%
show_isna(df_test)
# Out:
# Количество пропусков в каждом столбце:
# date                                          0.000000
# primary_cleaner.input.sulfate                 0.000756
# primary_cleaner.input.depressant              0.000945
# primary_cleaner.input.feed_size               0.000000
# primary_cleaner.input.xanthate                0.000756
# primary_cleaner.state.floatbank8_a_air        0.000000
# primary_cleaner.state.floatbank8_a_level      0.000000
# primary_cleaner.state.floatbank8_b_air        0.000000
# primary_cleaner.state.floatbank8_b_level      0.000000
# primary_cleaner.state.floatbank8_c_air        0.000000
# primary_cleaner.state.floatbank8_c_level      0.000000
# primary_cleaner.state.floatbank8_d_air        0.000000
# primary_cleaner.state.floatbank8_d_level      0.000000
# rougher.input.feed_ag                         0.000000
# rougher.input.feed_pb                         0.000000
# rougher.input.feed_rate                       0.000567
# ...

# %%
show_isna(df_train)
# Out:
# Количество пропусков в каждом столбце:
# date                                          0.000000
# final.output.concentrate_ag                   0.000071
# final.output.concentrate_pb                   0.000071
# final.output.concentrate_sol                  0.014913
# final.output.concentrate_au                   0.000000
#                                                 ...
# secondary_cleaner.state.floatbank5_a_level    0.000071
# secondary_cleaner.state.floatbank5_b_air      0.000071
# secondary_cleaner.state.floatbank5_b_level    0.000071
# secondary_cleaner.state.floatbank6_a_air      0.000141
# secondary_cleaner.state.floatbank6_a_level    0.000071
# Length: 87, dtype: float64
# Количество пропусков в каждом столбце:
# date                                          0.000000
# final.output.concentrate_ag                   0.000071
# final.output.concentrate_pb                   0.000071
# final.output.concentrate_sol                  0.014913
# ...

# %%
show_isna(df_full)
# Out:
# Количество пропусков в каждом столбце:
# date                                          0.000000
# final.output.concentrate_ag                   0.000051
# final.output.concentrate_pb                   0.000051
# final.output.concentrate_sol                  0.010854
# final.output.concentrate_au                   0.000000
#                                                 ...
# secondary_cleaner.state.floatbank5_a_level    0.000051
# secondary_cleaner.state.floatbank5_b_air      0.000051
# secondary_cleaner.state.floatbank5_b_level    0.000051
# secondary_cleaner.state.floatbank6_a_air      0.000103
# secondary_cleaner.state.floatbank6_a_level    0.000051
# Length: 87, dtype: float64
# Количество пропусков в каждом столбце:
# date                                          0.000000
# final.output.concentrate_ag                   0.000051
# final.output.concentrate_pb                   0.000051
# final.output.concentrate_sol                  0.010854
# ...

# %% [markdown]
# ### Вычисление MAE на обучающей выборке

# %% [markdown]
# Для того, чтобы исключить ошибку
#
#         ValueError: Input contains NaN, infinity or a value too large for dtype('float64')
#
# удалим пропуски из столбцов со значением NaN.

# %%
df_train.dropna(subset=['rougher.output.concentrate_au', 'rougher.input.feed_au',
                                   'rougher.output.tail_au','rougher.output.recovery'], inplace=True)

# %%
concentrate_au_column = df_train['rougher.output.concentrate_au']
feed_au_column = df_train['rougher.input.feed_au']
tail_au_column = df_train['rougher.output.tail_au']
input_recovery = df_train['rougher.output.recovery']
calculated_recovery = (concentrate_au_column * (feed_au_column - tail_au_column) / feed_au_column 
                        / (concentrate_au_column - tail_au_column) * 100)
print('Эффективность обогащения чернового концентрата:\n', calculated_recovery)
print('Абсолютная средняя ошибка =', mean_absolute_error(input_recovery, calculated_recovery))
# Out:
# Эффективность обогащения чернового концентрата:
#  0        87.107763
# 1        86.843261
# 2        86.842308
# 3        87.226430
# 4        86.688794
#            ...
# 14144    89.574376
# 14145    87.724007
# 14146    88.890579
# 14147    89.858126
# 14148    89.514960
# Length: 14149, dtype: float64
# Абсолютная средняя ошибка = 1.0748911125799084e-14

# %% [markdown]
# MAE имеет очень малое отклонение - это значит, что расчетное значение rougher.output.recovery совпадает с данными из столбца.
#
# Теперь подготовим данные по другим фреймам.

# %%
good_df_train = df_train.dropna()
good_df_train.isna().mean()
# Out:
# date                                          0.0
# final.output.concentrate_ag                   0.0
# final.output.concentrate_pb                   0.0
# final.output.concentrate_sol                  0.0
# final.output.concentrate_au                   0.0
#                                              ...
# secondary_cleaner.state.floatbank5_a_level    0.0
# secondary_cleaner.state.floatbank5_b_air      0.0
# secondary_cleaner.state.floatbank5_b_level    0.0
# secondary_cleaner.state.floatbank6_a_air      0.0
# secondary_cleaner.state.floatbank6_a_level    0.0
# Length: 87, dtype: float64

# %%
good_df_test = df_test.dropna()
good_df_test.isna().mean()
# Out:
# date                                          0.0
# primary_cleaner.input.sulfate                 0.0
# primary_cleaner.input.depressant              0.0
# primary_cleaner.input.feed_size               0.0
# primary_cleaner.input.xanthate                0.0
# primary_cleaner.state.floatbank8_a_air        0.0
# primary_cleaner.state.floatbank8_a_level      0.0
# primary_cleaner.state.floatbank8_b_air        0.0
# primary_cleaner.state.floatbank8_b_level      0.0
# primary_cleaner.state.floatbank8_c_air        0.0
# primary_cleaner.state.floatbank8_c_level      0.0
# primary_cleaner.state.floatbank8_d_air        0.0
# primary_cleaner.state.floatbank8_d_level      0.0
# rougher.input.feed_ag                         0.0
# rougher.input.feed_pb                         0.0
# rougher.input.feed_rate                       0.0
# rougher.input.feed_size                       0.0
# rougher.input.feed_sol                        0.0
# rougher.input.feed_au                         0.0
# ...

# %% [markdown]
# Скорее всего столбцы этапов rougher.output, rougher.calculation, final.output, primary_cleaner.output и secondary_cleaner.output отсутсвуют в тестовой выборке, так как рассчитываются позже.

# %%
good_df_test.head(5)
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# ...

# %%
good_df_test.columns
# Out:
# Index(['date', 'primary_cleaner.input.sulfate',
#        'primary_cleaner.input.depressant', 'primary_cleaner.input.feed_size',
#        'primary_cleaner.input.xanthate',
#        'primary_cleaner.state.floatbank8_a_air',
#        'primary_cleaner.state.floatbank8_a_level',
#        'primary_cleaner.state.floatbank8_b_air',
#        'primary_cleaner.state.floatbank8_b_level',
#        'primary_cleaner.state.floatbank8_c_air',
#        'primary_cleaner.state.floatbank8_c_level',
#        'primary_cleaner.state.floatbank8_d_air',
#        'primary_cleaner.state.floatbank8_d_level', 'rougher.input.feed_ag',
#        'rougher.input.feed_pb', 'rougher.input.feed_rate',
#        'rougher.input.feed_size', 'rougher.input.feed_sol',
#        'rougher.input.feed_au', 'rougher.input.floatbank10_sulfate',
#        'rougher.input.floatbank10_xanthate',
#        'rougher.input.floatbank11_sulfate',
#        'rougher.input.floatbank11_xanthate', 'rougher.state.floatbank10_a_air',
# ...

# %% [markdown]
# ### Определение столбцов для модели и их обраотка

# %%
#Выделим столбцы из тестовой выборки, по которым будем обучать модель

features_columns = good_df_test.columns[1:] # Оставим все столбцы кроме data, так как не несет никаког осмысла для обучения
rougher_features_columns = set(features_columns[12:34]) # Для предсказания rougher.output.recovery используем данные
#из стобцов rougher
final_features_columns = set(features_columns) # Тутбудем использовать все столбцы из тестовой выборки
print(rougher_features_columns)
print('\n', final_features_columns)
# Out:
# {'rougher.state.floatbank10_f_level', 'rougher.input.feed_pb', 'rougher.state.floatbank10_d_level', 'rougher.state.floatbank10_c_level', 'rougher.input.floatbank10_xanthate', 'rougher.input.floatbank10_sulfate', 'rougher.state.floatbank10_e_air', 'rougher.state.floatbank10_f_air', 'rougher.state.floatbank10_d_air', 'rougher.state.floatbank10_e_level', 'rougher.input.feed_sol', 'rougher.input.feed_ag', 'rougher.input.feed_rate', 'rougher.state.floatbank10_b_air', 'rougher.state.floatbank10_b_level', 'rougher.input.feed_au', 'rougher.state.floatbank10_c_air', 'rougher.input.floatbank11_xanthate', 'rougher.state.floatbank10_a_air', 'rougher.input.feed_size', 'rougher.state.floatbank10_a_level', 'rougher.input.floatbank11_sulfate'}
#
# ...

# %% [markdown]
# ### Гистограммы обогащения концентрата

# %%
plt.figure(figsize=[10,8])

plt.hist(good_df_train['rougher.output.recovery'], bins=90, color = 'green')

plt.xlim([0, 100])
plt.ylim([0, 700])

plt.xlabel("Эффективность обогащения чернового концентрата ")
plt.ylabel("Количество результатов")

plt.title("Гистограмма распределения по эффективности обогащения")
plt.show()

# %%
plt.figure(figsize=[10,8])

plt.hist(good_df_train['rougher.output.concentrate_au'], bins=100, color = 'green')

plt.xlim([0, 100])
plt.ylim([0, 700])

plt.xlabel("Эффективность обогащения чернового концентрата ")
plt.ylabel("Количество результатов")

plt.title("Доля золота в концентрате до очистки")
plt.show()

# %% [markdown]
# На гистограмме имеет много нулевых значений - из-за этого нужно подробнее их изучить и возможно удалить.

# %%
good_df_train[good_df_train['rougher.output.recovery'] < 1].head(4)
# Out:
#                    date  final.output.concentrate_ag  \
# 45  2016-01-16 21:00:00                     4.566664
# 46  2016-01-16 22:00:00                     4.577832
# 50  2016-01-17 03:00:00                     5.759800
# 51  2016-01-17 04:00:00                     5.807253
#
#     final.output.concentrate_pb  final.output.concentrate_sol  \
# 45                    10.406178                      4.588698
# 46                    10.691605                      5.274175
# 50                     9.537415                      3.997737
# 51                    10.439505                      6.512951
#
#     final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 45                    46.614456              68.403877             10.705777
# 46                    46.250638              70.675633             10.728531
# 50                    45.267942              68.638723             10.623064
# ...

# %%
good_df_train[good_df_train['rougher.output.concentrate_au'] < 1].head(4)
# Out:
#                    date  final.output.concentrate_ag  \
# 45  2016-01-16 21:00:00                     4.566664
# 46  2016-01-16 22:00:00                     4.577832
# 50  2016-01-17 03:00:00                     5.759800
# 51  2016-01-17 04:00:00                     5.807253
#
#     final.output.concentrate_pb  final.output.concentrate_sol  \
# 45                    10.406178                      4.588698
# 46                    10.691605                      5.274175
# 50                     9.537415                      3.997737
# 51                    10.439505                      6.512951
#
#     final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 45                    46.614456              68.403877             10.705777
# 46                    46.250638              70.675633             10.728531
# 50                    45.267942              68.638723             10.623064
# ...

# %%
#по столбцам где проходит этап rougher нет никаких данных - следовательно можем их удалить

good_df_train = good_df_train.drop(good_df_train[good_df_train['rougher.output.recovery'] == 0].index)
good_df_train[good_df_train['rougher.output.recovery'] < 1].head()
# Out:
# Empty DataFrame
# ...

# %%
# Построим гистограмму эффективности финального концентрата с обработанными данными
plt.figure(figsize=[12,9])

plt.hist(good_df_train['final.output.recovery'], bins=100, color = 'green')

plt.xlim([0, 110])
plt.ylim([0, 800])

plt.xlabel("Эффективность обогащения финального концентрата ")
plt.ylabel("Количество результатов")

plt.title("Гистограмма распределения по эффективности обогащения")
plt.show()

# %%
#Нулевые значение рассмотрим поближе и по возможности удалим
good_df_train[good_df_train['final.output.recovery'] < 1].head(4)
# Out:
#                      date  final.output.concentrate_ag  \
# 644   2016-02-13 11:00:00                          0.0
# 1193  2016-03-11 10:00:00                          0.0
# 1194  2016-03-11 11:00:00                          0.0
# 1195  2016-03-11 12:00:00                          0.0
#
#       final.output.concentrate_pb  final.output.concentrate_sol  \
# 644                           0.0                           0.0
# 1193                          0.0                           0.0
# 1194                          0.0                           0.0
# 1195                          0.0                           0.0
#
#       final.output.concentrate_au  final.output.recovery  \
# 644                           0.0                    0.0
# 1193                          0.0                    0.0
# 1194                          0.0                    0.0
# 1195                          0.0                    0.0
#
# ...

# %%
#Отсутсвуют данные в столбцах rougher, следоавательно можно их удалить
good_df_train = good_df_train.drop(good_df_train[good_df_train['final.output.recovery'] == 0].index)
good_df_train[good_df_train['final.output.recovery'] < 1].head()
# Out:
# Empty DataFrame
# ...

# %%
# Получили ровный датафрейм, который не содержит нулевые значения для нашей модели
good_df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10784 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                10784 non-null  object
#  1   final.output.concentrate_ag                         10784 non-null  float64
#  2   final.output.concentrate_pb                         10784 non-null  float64
#  3   final.output.concentrate_sol                        10784 non-null  float64
#  4   final.output.concentrate_au                         10784 non-null  float64
#  5   final.output.recovery                               10784 non-null  float64
#  6   final.output.tail_ag                                10784 non-null  float64
#  7   final.output.tail_pb                                10784 non-null  float64
# ...

# %% [markdown]
# **Вывод:**
#
#
#     По итогу подготовки данных были обнаружены следующие аномалии:
#
# - Пропущенные значения.
# - Нулевые значения в ключевых столбцах для нашей модели.
# - Были удалены значения которые могли повлият на работу модели (эти данные либо еще не занесли, либо еще не были получены).

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Анализ концентрации металлов (Au, Ag, Pb) на различных этапах очистки

# %%
# Золото
plt.figure(figsize=[12,9])

plt.hist(good_df_train['final.output.concentrate_au'], bins=100, label = 'final.output', alpha=.5, color = 'green')
plt.hist(good_df_train['primary_cleaner.output.concentrate_au'], bins=100, label = 'primary_cleaner.output', alpha=.5, color ='red')
plt.hist(good_df_train['rougher.output.concentrate_au'], bins=100, label = 'rougher.output', alpha=.5, color ='blue')

plt.xlim([0, 60])
plt.ylim([0, 1000])

plt.xlabel("Концентрация золота на выходе этапов")
plt.ylabel("Количество результатов")

plt.legend(loc='upper left', fontsize='x-large')

plt.title("Гистограмма распределения концентрации золота")
plt.show()

# %% [markdown]
# На гистограмме заметно, что концентрация золота повышается при каждом этапе - таким образом с помощью флотаации золото обощагается.

# %%
# Серебро
plt.figure(figsize=[12,9])

plt.hist(good_df_train['final.output.concentrate_ag'], bins=110, label = 'final.output', alpha=.5, color = 'orange')
plt.hist(good_df_train['primary_cleaner.output.concentrate_ag'], bins=110, label = 'primary_cleaner.output', alpha=.5, color = 'blue')
plt.hist(good_df_train['rougher.output.concentrate_ag'], bins=110, label = 'rougher.output', alpha=.5, color = 'red')

plt.xlim([0, 25])
plt.ylim([0, 700])

plt.xlabel("Концентрация серебра на выходе этапов")
plt.ylabel("Количество результатов")

plt.legend(loc='upper right', fontsize='x-large')

plt.title("Гистограмма распределения концентрации серебра")
plt.show()

# %% [markdown]
# Концентрация серебра понижается (справа на лево), а так как нас интересует золото, скорее всего другие материалы отделяются от сплава фильтруются или сортируются в нужном количестве.

# %%
#Свинец
plt.figure(figsize=[12,10])

plt.hist(good_df_train['final.output.concentrate_pb'], bins=100, label = 'final.output', alpha=.5, color = 'red')
plt.hist(good_df_train['primary_cleaner.output.concentrate_pb'], bins=100, label = 'primary_cleaner.output', alpha=.5, color = 'orange')
plt.hist(good_df_train['rougher.output.concentrate_pb'], bins=100, label = 'rougher.output', alpha=.5, color = 'blue')

plt.xlim([0, 20])
plt.ylim([0, 600])

plt.xlabel("Концентрация свинца на выходе этапов")
plt.ylabel("Количество результатов")

plt.legend(loc='upper left', fontsize='x-large')

plt.title("Гистограмма распределения концентрации свинца")
plt.show()

# %% [markdown]
# При пересечении графиков можно заметить, что концентрация свинца растет.

# %% [markdown]
# ### Гистограммы перед флотацией и первичной очисткой

# %%
# Перед флотацией
plt.figure(figsize=[13,10])

plt.hist(good_df_train['rougher.input.feed_size'], bins=220, label = 'Train rougher.input.feed_size', alpha=.55, color = 'orange')
plt.hist(good_df_test['rougher.input.feed_size'], bins=220, label = 'Test rougher.input.feed_size', alpha=.55, color = 'blue')

plt.xlim([0, 500])
plt.ylim([0, 1300])

plt.xlabel("Размер гранул сырья, меш")
plt.ylabel("Количество результатов")

plt.legend(loc='upper right', fontsize='x-large')

plt.title("Гистограмма распределения гранул сырья перед флотацией")
plt.show()

# %%
# Перед первичной очисткой
plt.figure(figsize=[12,9])

plt.hist(good_df_train['primary_cleaner.input.feed_size'], bins=100, density=True, label = 'Train primary_cleaner.input.feed_size', alpha=.5, color = 'red')
plt.hist(good_df_test['primary_cleaner.input.feed_size'], bins=100, density=True, label = 'Test primary_cleaner.input.feed_size', alpha=.5, color = 'green')

plt.xlim([0, 15])
plt.ylim([0, 4])

plt.xlabel("Размер гранул сырья")
plt.ylabel("Количество результатов")

plt.legend(loc='upper right', fontsize='x-large')

plt.title("Гистограмма распределения гранул сырья перед первичной очисткой")
plt.show()

# %% [markdown]
# Размер распределения нормализовался - то есть распределения почти наложились друг на друга.
#
# Теперь подготовим столбцы с концентрациями всех материалов в обучающей выборке по этапам и построим гистограмму.

# %% [markdown]
# ### Суммарная концентрация всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах

# %%
final_output_concentrate_sum_train = (good_df_train['final.output.concentrate_au'] + 
                                      good_df_train['final.output.concentrate_ag'] + 
                                      good_df_train['final.output.concentrate_pb'] +
                                      good_df_train['final.output.concentrate_sol'])
primary_cleaner_output_concentrate_sum_train = (good_df_train['rougher.input.feed_au'] + 
                                                good_df_train['rougher.input.feed_ag'] + 
                                                good_df_train['rougher.input.feed_pb'] +
                                                good_df_train['rougher.input.feed_sol'])
rougher_output_concentrate_sum_train = (good_df_train['rougher.output.concentrate_au'] + 
                                        good_df_train['rougher.output.concentrate_ag'] + 
                                        good_df_train['rougher.output.concentrate_pb'] +
                                        good_df_train['rougher.output.concentrate_sol'])

# %%
plt.figure(figsize=[12,9])

plt.hist(final_output_concentrate_sum_train, bins=100, label = 'final_output', alpha=.4)
plt.hist(primary_cleaner_output_concentrate_sum_train, bins=100, label = 'primary_cleaner_output', alpha=.5)
plt.hist(rougher_output_concentrate_sum_train, bins=100, label = 'rougher_output', alpha=.4)

plt.xlim([0, 100])
plt.ylim([0, 1400])

plt.xlabel("Сум. концентраця")
plt.ylabel("Количество результатов")

plt.legend(loc='upper left', fontsize='x-large')

plt.title("Гистограмма распределения концентраций на разных этапах очистки")
plt.show()

# %% [markdown]
# В нулевых значениях много аномалий - их нужно обработать.

# %%
#Найдем их количество
good_df_train[good_df_train['primary_cleaner.output.concentrate_au'] < 1]['primary_cleaner.output.concentrate_au'].count()
# Out:
# 109

# %%
#Удалим их 
good_df_train = good_df_train.drop(good_df_train[good_df_train['primary_cleaner.output.concentrate_au'] == 0].index)
good_df_train[good_df_train['primary_cleaner.output.concentrate_au'] == 0].head()
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# **Вывод:**
#
#     В результате анализа были изучены:
#
# - Концентрация металлов (Au, Ag, Pb) на разных этапах очистки.
# - Размер гранул сырья на обучающей и тестовой выборках.
# - Суммарная концентрация всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.
# - Найдены и обработаны аномалии.

# %% [markdown]
# ## Модель

# %% [markdown]
# ### Функция для вычисления sMAPE

# %%
def sMAPE(y_true,y_pred):
    error = np.mean(abs(y_true - y_pred)/((abs(y_true)+abs(y_pred))/2))*100
    return error

# %%
def final_sMAPE(sMAPE_rougher,sMAPE_final):
    return (0.25*sMAPE_rougher + 0.75*sMAPE_final)

# %%
# Подготовка признаков для final.output.recovery
columns_to_delete = set(good_df_train.columns) - final_features_columns
print(columns_to_delete)
train_features_dataset_final = good_df_train.drop(columns_to_delete, axis=1)
print('\n',train_features_dataset_final.columns)
# Out:
# {'final.output.tail_sol', 'rougher.calculation.au_pb_ratio', 'primary_cleaner.output.concentrate_pb', 'date', 'rougher.output.tail_au', 'rougher.output.tail_sol', 'rougher.output.tail_ag', 'primary_cleaner.output.concentrate_ag', 'final.output.concentrate_au', 'rougher.output.recovery', 'rougher.output.concentrate_au', 'secondary_cleaner.output.tail_sol', 'primary_cleaner.output.concentrate_sol', 'final.output.recovery', 'rougher.output.tail_pb', 'secondary_cleaner.output.tail_au', 'primary_cleaner.output.tail_au', 'final.output.concentrate_sol', 'rougher.calculation.floatbank11_sulfate_to_au_feed', 'primary_cleaner.output.tail_ag', 'final.output.tail_ag', 'secondary_cleaner.output.tail_pb', 'final.output.tail_pb', 'rougher.output.concentrate_ag', 'primary_cleaner.output.tail_sol', 'final.output.tail_au', 'final.output.concentrate_pb', 'rougher.output.concentrate_sol', 'primary_cleaner.output.concentrate_au', 'rougher.calculation.sulfate_to_au_concentrate', 'secondary_cleaner.output.
# ...

# %%
#Подготовка признаков для rougher.output.recovery
columns_to_delete = set(train_features_dataset_final.columns) - rougher_features_columns
print(columns_to_delete)
train_features_dataset_rougher = train_features_dataset_final.drop(columns_to_delete, axis=1)
print('\n',train_features_dataset_rougher.columns)
# Out:
# {'secondary_cleaner.state.floatbank5_b_air', 'secondary_cleaner.state.floatbank4_b_air', 'primary_cleaner.input.sulfate', 'primary_cleaner.state.floatbank8_c_level', 'secondary_cleaner.state.floatbank4_b_level', 'primary_cleaner.state.floatbank8_d_air', 'secondary_cleaner.state.floatbank3_b_air', 'secondary_cleaner.state.floatbank6_a_air', 'primary_cleaner.state.floatbank8_a_air', 'secondary_cleaner.state.floatbank3_b_level', 'secondary_cleaner.state.floatbank2_a_level', 'secondary_cleaner.state.floatbank2_b_level', 'secondary_cleaner.state.floatbank5_b_level', 'secondary_cleaner.state.floatbank6_a_level', 'primary_cleaner.state.floatbank8_d_level', 'primary_cleaner.state.floatbank8_a_level', 'secondary_cleaner.state.floatbank4_a_level', 'secondary_cleaner.state.floatbank3_a_level', 'primary_cleaner.state.floatbank8_b_level', 'primary_cleaner.state.floatbank8_c_air', 'secondary_cleaner.state.floatbank2_a_air', 'secondary_cleaner.state.floatbank5_a_level', 'primary_cleaner.input.xanth
# ...

# %% [markdown]
# ### Обучение моделей и оценка их качества

# %%
train_target_dataset_rougher = good_df_train['rougher.output.recovery']
train_target_dataset_final = good_df_train['final.output.recovery']

# %%
test_features = good_df_test.drop('date', axis=1)

# %%
test_features_final = test_features
columns_to_delete = set(test_features_final.columns) - rougher_features_columns
test_features_rougher = test_features_final.drop(columns_to_delete, axis=1)

# %%
test_features_rougher.shape
# Out:
# (5229, 22)

# %%
# Cчетчик функции
custom_score = make_scorer(sMAPE,greater_is_better=False)

# %%
model = make_pipeline(StandardScaler(),RandomForestRegressor())
model2 = make_pipeline(StandardScaler(),DecisionTreeRegressor())

# %%
# Инициализация параметров для GridSearchCV
params_RF = {"randomforestregressor__n_estimators":[5,100],
             "randomforestregressor__max_depth":[1,10]}
params_DT= {"decisiontreeregressor__max_depth":[1,10]}

# %%
grid_rougher = GridSearchCV(model,param_grid = params_RF,scoring=custom_score)
grid_final = GridSearchCV(model,param_grid = params_RF,scoring=custom_score)
grid_rougher_DT = GridSearchCV(model2,param_grid = params_DT,scoring=custom_score)
grid_final_DT = GridSearchCV(model2,param_grid = params_DT,scoring=custom_score)

# %%
# Запускаем обучение
grid_rougher.fit(train_features_dataset_rougher,train_target_dataset_rougher)
grid_final.fit(train_features_dataset_final,train_target_dataset_final)
grid_rougher_DT.fit(train_features_dataset_rougher,train_target_dataset_rougher)
grid_final_DT.fit(train_features_dataset_final,train_target_dataset_final)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('decisiontreeregressor',
#                                         DecisionTreeRegressor())]),
#              param_grid={'decisiontreeregressor__max_depth': [1, 10]},
#              scoring=make_scorer(sMAPE, greater_is_better=False))

# %%
print("Лучшие модели")
print(grid_rougher.best_estimator_)
print(grid_rougher.best_estimator_)
print(grid_rougher_DT.best_estimator_)
print(grid_final_DT.best_estimator_)
# Out:
# Лучшие модели
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestregressor', RandomForestRegressor(max_depth=10))])
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestregressor', RandomForestRegressor(max_depth=10))])
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('decisiontreeregressor', DecisionTreeRegressor(max_depth=1))])
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('decisiontreeregressor', DecisionTreeRegressor(max_depth=1))])

# %%
best_score_rougher = grid_rougher.best_score_
best_score_final = grid_final.best_score_
best_score_rougher_DT = grid_rougher_DT.best_score_
best_score_final_DT = grid_final_DT.best_score_

# %%
# Определяем лучшую модель для каждого целевого признака
print("rougher")
print("RandomForest",best_score_rougher,"DecisionTree",best_score_rougher_DT)
print("final")
print("RandomForest",best_score_final,"DecisionTree",best_score_final_DT)
# Out:
# rougher
# RandomForest -6.326175994682906 DecisionTree -6.970277417780467
# final
# RandomForest -8.151201721878596 DecisionTree -8.21112354446667

# %% [markdown]
# **Вывод:**
#
# Наилучшей моделью по метрикам является случайный лес, так что остановим свой выбор на нем.

# %% [markdown]
# ### Лучший результат тренировочной выборки

# %%
# Финальный sMAPE RandomForest
final_sMAPE(best_score_rougher,best_score_final)
# Out:
# -7.694945290079674

# %%
# Финальный sMAPE DecisionTree
final_sMAPE(best_score_rougher_DT,best_score_final_DT)
# Out:
# -7.90091201279512

# %%
test_frame_for_target = good_df_test.merge(df_full.loc[:,['date',"rougher.output.recovery",
                                                           "final.output.recovery"]],on = 'date')

# %%
target_test_rougher = test_frame_for_target["rougher.output.recovery"]
target_test_final = test_frame_for_target["final.output.recovery"]

# %%
target_test_final, target_test_rougher
# Out:
# (0       70.273583
#  1       68.910432
#  2       68.143213
#  3       67.776393
#  4       61.467078
#            ...
#  5224    68.919891
#  5225    68.440582
#  5226    67.092759
#  5227    68.061186
#  5228    71.699976
#  Name: final.output.recovery, Length: 5229, dtype: float64,
#  0       89.993421
#  1       88.089657
#  2       88.412756
#  3       87.360133
#  4       83.236367
#            ...
#  5224    95.172585
#  5225    94.575036
#  5226    93.018138
#  5227    92.599042
#  5228    91.177695
#  Name: rougher.output.recovery, Length: 5229, dtype: float64)

# %%
not_nan_index = set(test_features_rougher.index)
rougher_recovery_real = df_full.loc[not_nan_index,'rougher.output.recovery']
final_recovery_real = df_full.loc[test_features_final.index,'final.output.recovery']
not_nan_index = not_nan_index.intersection(set(final_recovery_real.index), set(rougher_recovery_real.index))

# %%
final_recovery_real = df_full.loc[not_nan_index,'final.output.recovery']
test_features_rougher = test_features_rougher.loc[not_nan_index,:]
test_features_final = test_features_final.loc[not_nan_index,:]

# %%
rogher_test = grid_rougher.predict(test_features_rougher)

# %%
final_test = grid_final.predict(test_features_final)

# %% [markdown]
# ### Ошибка тестовой выборки

# %%
final_sMAPE(sMAPE(target_test_rougher,rogher_test),sMAPE(target_test_final,final_test))
# Out:
# 8.77164399530824

# %% [markdown]
# ### Анализ константной модели

# %%
dummy_regressor_rougher = DummyRegressor(strategy="median")
dummy_regressor_rougher.fit(train_features_dataset_rougher,train_target_dataset_rougher)
dummy_rougher_pred = dummy_regressor_rougher.predict(rogher_test)
smape_dummy_rougher = sMAPE(target_test_rougher, dummy_rougher_pred)
print(smape_dummy_rougher)
# Out:
# 8.612817646733882

# %%
dummy_regressor_final = DummyRegressor(strategy="median")
dummy_regressor_final.fit(train_features_dataset_final,train_target_dataset_final)
dummy_final_pred = dummy_regressor_final.predict(final_test)
smape_dummy_final = sMAPE(target_test_final, dummy_final_pred)
print(smape_dummy_final)
# Out:
# 9.255690881560383

# %%
final = (smape_dummy_final + smape_dummy_rougher)/2
final
# Out:
# 8.934254264147132

# %% [markdown]
# **Вывод:**
#
# - Изначально были проведены проверки на дубликаты и числовые значения, по которым из-за переизбытка данным сложно была определить количество пропусков. Поэтому была создана функция анализа пропусков, и по итогу MAE имеет очень малое отклонение - это значит, что расчетное значение rougher.output.recovery совпадает с данными из столбца.
# - В результате обучения моделей (дерево решений, случайный лес, линейная регрессия) была найдена лучшая модель - это модель случайный лес.
# - С помощью построенных гистрограмм было
#
#
# - Ошибка тестовой выборки равна = 8.767918440927875
# - Ошибка константной выборки равна = 8.934254264147132
# - Лучшим результатом тренировочной модели стало:
#
#
#     Финальный sMAPE RandomForest = -7.683258154242512
#     Финальный sMAPE DecisionTree = -7.900912012795125

# %% [markdown]
# # Чек-лист готовности проекта

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [ ]  Весь код выполняется без ошибок
# - [ ]  Ячейки с кодом расположены в порядке выполнения
# - [ ]  Выполнен шаг 1: данные подготовлены
#     - [ ]  Проверена формула вычисления эффективности обогащения
#     - [ ]  Проанализированы признаки, недоступные в тестовой выборке
#     - [ ]  Проведена предобработка данных
# - [ ]  Выполнен шаг 2: данные проанализированы
#     - [ ]  Исследовано изменение концентрации элементов на каждом этапе
#     - [ ]  Проанализированы распределения размеров гранул на обучающей и тестовой выборках
#     - [ ]  Исследованы суммарные концентрации
# - [ ]  Выполнен шаг 3: построена модель прогнозирования
#     - [ ]  Написана функция для вычисления итогового *sMAPE*
#     - [ ]  Обучено и проверено несколько моделей
#     - [ ]  Выбрана лучшая модель, её качество проверено на тестовой выборке
